# %%
# !pip install luwiji

# %%
from luwiji.knn import illustration, demo

# %%
demo.knn()
# Out:
# interactive(children=(IntSlider(value=1, description='N', max=11, min=1, step=2), FloatSlider(value=-5.0, desc…

# %%
illustration.knn_distance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 10) #linscape is a numpy function that creates a lsit array
y = np.square(x)

# %%
Fig = plt.figure(figsize = (6, 6)) #preparing the figure
ax = plt.axes() # prepare teh axes and

# %%
Fig = plt.figure(figsize = (6, 6)) #preparing the figure
ax = plt.axes()
ax.plot(x,y)
ax = plt.axes()
ax.plot(x, y)

# %%
x = np.linspace(0, 10, 100)
y = np.sqrt(x)
y1 = np.sin(x)
y2 = np.cos(x)

Fig = plt.figure(figsize = (6, 6)) #preparing the figure
ax = plt.axes()
ax.plot(x,y)
ax = plt.axes()
ax.plot(x, y1)
ax.plot(x, y2);

# %%
#shortcut without cariable

# %%
plt.figure(figsize= (6, 6))
plt.plot(x, y1)
plt.plot(x, y2);

# %%
#modifying the graphs

# %%
plt.figure(figsize=(6,6))
plt.plot(x, y1, 'r-.', linewidth=7)
plt.plot(x, y2, 'bo', markersize = 37);
plt.xlim(0, 10) #xaxis limit
plt.ylim(0, 1.5) #set the yaxis limit
plt.axis('equal') #force np to balance teh data
# Out:
# (np.float64(-0.5),
#  np.float64(10.5),
#  np.float64(-1.0999445244849302),
#  np.float64(1.0999973583088063))

# %%
#axes name, title and legend

# %%
plt.figure(figsize=(6,6))
plt.plot(x, y1, 'r-.', linewidth=7)
plt.plot(x, y2, 'bo', markersize = 37);
plt.xlim(0, 10) #xaxis limit
plt.ylim(0, 1.5) #set the yaxis limit
plt.axis('equal')
ax.set_xlabel()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 7
#       5 plt.ylim(0, 1.5) #set the yaxis limit
#       6 plt.axis('equal')
# ----> 7 ax.set_xlabel()
#
# TypeError: _AxesBase.set_xlabel() missing 1 required positional argument: 'xlabel'

# %%
#scatter plot

# %%
df = pd.read_csv('circle_data.csv', delimiter=';') #put sep to create table on csv
#df = pd.read_csv('circle_data.csv', sep=';') #put sep to create table on csv
df.head()
# Out:
#           x         y    radius
# 0  0.064608  0.548028  0.551823
# 1 -0.277651  0.424200  0.506987
# 2 -0.477146 -0.157482  0.502463
# 3  0.031218 -0.169573  0.172423
# 4 -0.048724  0.736632  0.738242

# %%
x = df['x']
y = df['y']
rad = df.radius
plt.scatter(x,y);
plt.axis('equal');

# %%
#change color

# %%
plt.scatter(x, y, c=rad, s=rad*90, cmap = 'seismic') #cmap is color red
plt.axis('equal');

# %%
#histogram

# %%
number = np.random.randn(10000) #randn is random normal
plt.hist(number, bins = 25); #bins = rands of values (bucket) to group data in histogram

# %%
#subplot

# %%
fig, ax = plt.subplots(2,3, figsize = (12, 6))
ax[0, 0].hist(number, bins = 20) #start from 0
ax[0, 1].hist(number, bins = 20) #1st row, 3rd row
ax[1, 0].hist(number, bins = 20) #2nd row, 1st column
# Out:
# (array([1.000e+00, 8.000e+00, 2.700e+01, 5.100e+01, 9.900e+01, 2.300e+02,
#         4.650e+02, 7.640e+02, 1.090e+03, 1.448e+03, 1.561e+03, 1.436e+03,
#         1.099e+03, 7.930e+02, 4.760e+02, 2.630e+02, 1.160e+02, 5.000e+01,
#         1.400e+01, 9.000e+00]),
#  array([-4.05095669, -3.6675532 , -3.28414971, -2.90074622, -2.51734273,
#         -2.13393925, -1.75053576, -1.36713227, -0.98372878, -0.60032529,
#         -0.21692181,  0.16648168,  0.54988517,  0.93328866,  1.31669214,
#          1.70009563,  2.08349912,  2.46690261,  2.8503061 ,  3.23370958,
#          3.61711307]),
#  <BarContainer object of 20 artists>)
